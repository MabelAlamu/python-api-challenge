# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
 # List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 601

# %%
base_url= 'https://api.openweathermap.org/data/2.5/weather?'

query_url = base_url + "appid=" + weather_api_key + "&q="

#data= requests.get(query_url).json()
#print(data)

# %%
city_name= []
temp= []
humidity= []
cloudiness= []
wind_speed= []
latitude= []
longtitude= []
country=[]
date=[]

record = 1


print(f"Beginning Data Retrieval")
print(f"-----------------------------")

for city in cities:
    response= requests.get(f"{query_url}{city}").json()
    
    try:
        city_name.append(response["name"])
        temp.append(response['main']['temp'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        latitude.append(response['coord']['lat'])
        longtitude.append(response['coord']['lon'])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        
        
        record= record + 1

        
        print(f"Processing Record {record}|{city}")
      
    except:
        print(f"City not found. Skipping...")
        pass
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 2|albany
# Processing Record 3|lata
# Processing Record 4|thompson
# Processing Record 5|saint-philippe
# Processing Record 6|meulaboh
# Processing Record 7|rikitea
# Processing Record 8|mama
# Processing Record 9|mataura
# Processing Record 10|jamestown
# Processing Record 11|claremore
# Processing Record 12|lebu
# Processing Record 13|puerto del rosario
# Processing Record 14|leningradskiy
# Processing Record 15|cutlerville
# Processing Record 16|araouane
# Processing Record 17|nueva londres
# Processing Record 18|luderitz
# Processing Record 19|batagay
# Processing Record 20|ayagoz
# Processing Record 21|dicabisagan
# Processing Record 22|hithadhoo
# Processing Record 23|hobart
# Processing Record 24|cape town
# City not found. Skipping...
# Processing Record 25|qaqortoq
# Processing Record 26|avarua
# Processing Record 27|jambi
# Processing Record 28|poltava
# Processing Record 29|bluff
# Processing Record 30|cherskiy
# Processing Record 31|hermanus
# Processing Record 32|maryville
# Processing Record 33|pevek
# Processing Record 34|namibe
# Processing Record 35|carnarvon
# Processing Record 36|shache
# Processing Record 37|tromso
# Processing Record 38|east london
# Processing Record 39|zhoucheng
# Processing Record 40|dali
# Processing Record 41|chokurdakh
# Processing Record 42|otane
# City not found. Skipping...
# Processing Record 43|tungor
# Processing Record 44|ponta do sol
# Processing Record 45|severo-kurilsk
# Processing Record 46|souillac
# Processing Record 47|puerto ayora
# Processing Record 48|khatanga
# Processing Record 49|ushuaia
# Processing Record 50|moree
# Processing Record 51|ilulissat
# Processing Record 52|treinta y tres
# Processing Record 53|nouadhibou
# Processing Record 54|kumluca
# Processing Record 55|vaini
# Processing Record 56|hilo
# City not found. Skipping...
# Processing Record 57|maningrida
# Processing Record 58|kattivakkam
# Processing Record 59|port alfred
# Processing Record 60|pacific grove
# Processing Record 61|caconda
# Processing Record 62|sterling
# Processing Record 63|kirakira
# Processing Record 64|jardim
# Processing Record 65|okato
# Processing Record 66|arraial do cabo
# Processing Record 67|nome
# City not found. Skipping...
# Processing Record 68|saskylakh
# Processing Record 69|riyadh
# Processing Record 70|varhaug
# Processing Record 71|broken hill
# Processing Record 72|atuona
# Processing Record 73|hay river
# Processing Record 74|roebourne
# Processing Record 75|cernay
# Processing Record 76|geraldton
# Processing Record 77|bredasdorp
# Processing Record 78|inhambane
# Processing Record 79|castro
# City not found. Skipping...
# Processing Record 80|pangai
# Processing Record 81|ushtobe
# Processing Record 82|yichun
# Processing Record 83|tuktoyaktuk
# Processing Record 84|punta arenas
# Processing Record 85|ust-nera
# Processing Record 86|padang
# Processing Record 87|marzuq
# Processing Record 88|kargasok
# Processing Record 89|nanortalik
# Processing Record 90|clearwater
# Processing Record 91|hovd
# Processing Record 92|sechura
# Processing Record 93|muzhi
# Processing Record 94|inirida
# Processing Record 95|bawku
# Processing Record 96|sitka
# Processing Record 97|flin flon
# Processing Record 98|shihezi
# Processing Record 99|mayor pablo lagerenza
# Processing Record 100|belyy yar
# Processing Record 101|acapulco
# City not found. Skipping...
# Processing Record 102|mount gambier
# Processing Record 103|faanui
# Processing Record 104|miami beach
# Processing Record 105|dikson
# Processing Record 106|hami
# Processing Record 107|kaeo
# Processing Record 108|kodiak
# Processing Record 109|codrington
# Processing Record 110|kapaa
# Processing Record 111|busselton
# Processing Record 112|palembang
# Processing Record 113|kavieng
# Processing Record 114|bethel
# City not found. Skipping...
# Processing Record 115|esmeralda
# Processing Record 116|longyearbyen
# Processing Record 117|milkovo
# Processing Record 118|huarmey
# Processing Record 119|hunterville
# City not found. Skipping...
# Processing Record 120|karratha
# Processing Record 121|beringovskiy
# Processing Record 122|kaitangata
# Processing Record 123|andra
# Processing Record 124|westport
# Processing Record 125|yellowknife
# City not found. Skipping...
# Processing Record 126|vestmannaeyjar
# Processing Record 127|isilkul
# Processing Record 128|gora
# Processing Record 129|morondava
# Processing Record 130|darnah
# Processing Record 131|cairns
# Processing Record 132|hambantota
# Processing Record 133|tokur
# Processing Record 134|svetlyy
# Processing Record 135|umm lajj
# Processing Record 136|hasaki
# Processing Record 137|provideniya
# Processing Record 138|taber
# Processing Record 139|amapa
# Processing Record 140|jalu
# Processing Record 141|mar del plata
# Processing Record 142|chuy
# Processing Record 143|noumea
# Processing Record 144|ancud
# Processing Record 145|mantua
# Processing Record 146|nikolskoye
# Processing Record 147|berlevag
# Processing Record 148|cassilandia
# Processing Record 149|iguape
# Processing Record 150|coahuayana
# Processing Record 151|kuruman
# Processing Record 152|sur
# Processing Record 153|butaritari
# Processing Record 154|banda aceh
# Processing Record 155|dauriya
# Processing Record 156|solok
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 157|visby
# Processing Record 158|sola
# City not found. Skipping...
# Processing Record 159|bengkulu
# Processing Record 160|toccoa
# Processing Record 161|harper
# Processing Record 162|dingle
# City not found. Skipping...
# Processing Record 163|ketchikan
# Processing Record 164|santiago
# Processing Record 165|pisco
# Processing Record 166|broome
# Processing Record 167|lompoc
# Processing Record 168|airai
# Processing Record 169|fare
# Processing Record 170|poya
# Processing Record 171|atikokan
# Processing Record 172|kavaratti
# City not found. Skipping...
# Processing Record 173|leeuwarden
# Processing Record 174|mangrol
# Processing Record 175|port macquarie
# Processing Record 176|esperance
# Processing Record 177|port elizabeth
# Processing Record 178|cukai
# City not found. Skipping...
# Processing Record 179|bandarban
# Processing Record 180|seydi
# Processing Record 181|saint-augustin
# Processing Record 182|talnakh
# Processing Record 183|flinders
# Processing Record 184|innisfail
# Processing Record 185|mapiripan
# Processing Record 186|barrow
# Processing Record 187|kloulklubed
# Processing Record 188|san cristobal
# Processing Record 189|cockburn town
# Processing Record 190|sao filipe
# Processing Record 191|nishihara
# Processing Record 192|manokwari
# Processing Record 193|roald
# Processing Record 194|shumskiy
# Processing Record 195|krasnokamensk
# Processing Record 196|bintulu
# Processing Record 197|mahebourg
# Processing Record 198|los llanos de aridane
# Processing Record 199|yar-sale
# Processing Record 200|upernavik
# Processing Record 201|inuvik
# Processing Record 202|korla
# Processing Record 203|tadine
# Processing Record 204|isangel
# City not found. Skipping...
# Processing Record 205|taltal
# Processing Record 206|tsiroanomandidy
# City not found. Skipping...
# Processing Record 207|yebaishou
# Processing Record 208|barsovo
# Processing Record 209|erdenet
# Processing Record 210|coihaique
# Processing Record 211|kingman
# Processing Record 212|paro
# Processing Record 213|fairbanks
# Processing Record 214|bosobolo
# Processing Record 215|omsukchan
# Processing Record 216|georgetown
# Processing Record 217|beloha
# Processing Record 218|palmer
# Processing Record 219|semey
# City not found. Skipping...
# Processing Record 220|caravelas
# Processing Record 221|progreso
# Processing Record 222|salalah
# Processing Record 223|alyangula
# Processing Record 224|tezu
# Processing Record 225|parrita
# Processing Record 226|sorland
# Processing Record 227|balkanabat
# Processing Record 228|alexandria
# City not found. Skipping...
# Processing Record 229|beba
# Processing Record 230|bhadra
# Processing Record 231|jertih
# Processing Record 232|gat
# Processing Record 233|ilebo
# Processing Record 234|dukat
# Processing Record 235|sept-iles
# Processing Record 236|whitehorse
# Processing Record 237|safford
# Processing Record 238|tevriz
# Processing Record 239|la reforma
# Processing Record 240|oni
# Processing Record 241|nuuk
# Processing Record 242|saint-francois
# Processing Record 243|norman wells
# Processing Record 244|nichinan
# Processing Record 245|bonthe
# Processing Record 246|peranamallur
# Processing Record 247|aripuana
# Processing Record 248|portree
# Processing Record 249|saint george
# Processing Record 250|victoria
# Processing Record 251|qaanaaq
# Processing Record 252|mandalgovi
# City not found. Skipping...
# Processing Record 253|new norfolk
# Processing Record 254|sarangani
# Processing Record 255|qui nhon
# Processing Record 256|visani
# Processing Record 257|okha
# City not found. Skipping...
# Processing Record 258|sines
# Processing Record 259|guerrero negro
# City not found. Skipping...
# Processing Record 260|malumfashi
# Processing Record 261|faya
# Processing Record 262|diamantino
# Processing Record 263|nova varos
# Processing Record 264|eyl
# Processing Record 265|bukachacha
# Processing Record 266|najran
# Processing Record 267|college
# Processing Record 268|salinas
# Processing Record 269|de-kastri
# Processing Record 270|cabo san lucas
# Processing Record 271|tsumeb
# Processing Record 272|kita
# Processing Record 273|margate
# Processing Record 274|marrakesh
# Processing Record 275|sioux lookout
# Processing Record 276|torbay
# Processing Record 277|shimoda
# Processing Record 278|todos santos
# Processing Record 279|yangambi
# Processing Record 280|kahului
# Processing Record 281|tiksi
# Processing Record 282|uray
# Processing Record 283|tasiilaq
# Processing Record 284|sao gabriel da cachoeira
# Processing Record 285|alice springs
# Processing Record 286|nantucket
# Processing Record 287|mitsamiouli
# Processing Record 288|vila velha
# Processing Record 289|khandyga
# Processing Record 290|high level
# Processing Record 291|vao
# Processing Record 292|iqaluit
# Processing Record 293|cidreira
# Processing Record 294|herat
# Processing Record 295|ixtapa
# Processing Record 296|talaya
# Processing Record 297|bosaso
# Processing Record 298|launceston
# Processing Record 299|muyezerskiy
# City not found. Skipping...
# Processing Record 300|abu dhabi
# Processing Record 301|lagoa
# Processing Record 302|lorengau
# Processing Record 303|katsuura
# Processing Record 304|suntar
# Processing Record 305|shingu
# Processing Record 306|sibi
# Processing Record 307|mamit
# Processing Record 308|ballina
# Processing Record 309|ferme-neuve
# Processing Record 310|asau
# Processing Record 311|byron bay
# Processing Record 312|rawson
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 313|nadym
# Processing Record 314|wyszkow
# Processing Record 315|bardstown
# Processing Record 316|naze
# Processing Record 317|aklavik
# Processing Record 318|ahipara
# Processing Record 319|saldanha
# Processing Record 320|port-cartier
# Processing Record 321|bani walid
# Processing Record 322|goderich
# Processing Record 323|tuatapere
# Processing Record 324|hopkinsville
# Processing Record 325|livingston
# Processing Record 326|muros
# Processing Record 327|matara
# Processing Record 328|ulsteinvik
# Processing Record 329|chenghai
# Processing Record 330|turukhansk
# Processing Record 331|guaimaro
# Processing Record 332|kilindoni
# City not found. Skipping...
# Processing Record 333|kurilsk
# Processing Record 334|vuktyl
# Processing Record 335|bilibino
# Processing Record 336|aberdeen
# Processing Record 337|kutum
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 338|yelovo
# Processing Record 339|hofn
# Processing Record 340|ayan
# Processing Record 341|srednekolymsk
# Processing Record 342|casa nova
# Processing Record 343|chapais
# Processing Record 344|murindo
# Processing Record 345|itarema
# Processing Record 346|evensk
# Processing Record 347|port lincoln
# Processing Record 348|yulara
# Processing Record 349|havelock
# Processing Record 350|gamba
# Processing Record 351|ribeira grande
# Processing Record 352|ambilobe
# Processing Record 353|port hardy
# Processing Record 354|lavrentiya
# Processing Record 355|port hawkesbury
# Processing Record 356|leh
# Processing Record 357|kathu
# Processing Record 358|susanville
# Processing Record 359|kiruna
# Processing Record 360|hualmay
# Processing Record 361|sangar
# Processing Record 362|tual
# Processing Record 363|nelson bay
# Processing Record 364|kuusamo
# Processing Record 365|van
# Processing Record 366|kailua
# Processing Record 367|bluefields
# Processing Record 368|saint-pierre
# Processing Record 369|sabang
# Processing Record 370|bambous virieux
# Processing Record 371|laguna
# Processing Record 372|areosa
# Processing Record 373|houma
# Processing Record 374|guarapari
# Processing Record 375|morehead
# Processing Record 376|ramnicu sarat
# Processing Record 377|along
# Processing Record 378|jalpa
# Processing Record 379|sistranda
# Processing Record 380|dapaong
# Processing Record 381|clyde river
# Processing Record 382|constitucion
# Processing Record 383|kudahuvadhoo
# Processing Record 384|fengrun
# Processing Record 385|kardla
# Processing Record 386|pitimbu
# Processing Record 387|mizan teferi
# Processing Record 388|prudentopolis
# City not found. Skipping...
# Processing Record 389|camacha
# Processing Record 390|traverse city
# Processing Record 391|rio gallegos
# Processing Record 392|payson
# Processing Record 393|fillan
# Processing Record 394|visnes
# City not found. Skipping...
# Processing Record 395|zhezkazgan
# Processing Record 396|boende
# Processing Record 397|catamarca
# Processing Record 398|pingliang
# City not found. Skipping...
# Processing Record 399|manggar
# Processing Record 400|ulan-ude
# City not found. Skipping...
# Processing Record 401|severo-yeniseyskiy
# Processing Record 402|juneau
# Processing Record 403|tilichiki
# City not found. Skipping...
# Processing Record 404|nerja
# Processing Record 405|college station
# Processing Record 406|farafangana
# Processing Record 407|merauke
# Processing Record 408|smithers
# Processing Record 409|xinyang
# City not found. Skipping...
# Processing Record 410|zhigansk
# Processing Record 411|port-gentil
# Processing Record 412|the valley
# Processing Record 413|lesosibirsk
# Processing Record 414|alta floresta
# Processing Record 415|pedernales
# Processing Record 416|alta
# Processing Record 417|deniliquin
# Processing Record 418|buta
# Processing Record 419|fukue
# Processing Record 420|menomonie
# Processing Record 421|tunceli
# Processing Record 422|tabou
# City not found. Skipping...
# Processing Record 423|husavik
# Processing Record 424|kamenka
# Processing Record 425|do gonbadan
# Processing Record 426|necochea
# Processing Record 427|kasongo-lunda
# Processing Record 428|te anau
# Processing Record 429|alofi
# Processing Record 430|shoranur
# Processing Record 431|malinovoye ozero
# City not found. Skipping...
# Processing Record 432|yuxia
# Processing Record 433|sibolga
# Processing Record 434|west bay
# Processing Record 435|komsomolskiy
# Processing Record 436|hrubieszow
# Processing Record 437|catuday
# Processing Record 438|kruisfontein
# Processing Record 439|jodar
# Processing Record 440|pahalgam
# Processing Record 441|karatau
# Processing Record 442|eregli
# City not found. Skipping...
# Processing Record 443|korem
# Processing Record 444|jinji
# Processing Record 445|san patricio
# Processing Record 446|manaure
# City not found. Skipping...
# Processing Record 447|belmonte
# Processing Record 448|lashio
# Processing Record 449|rocha
# City not found. Skipping...
# Processing Record 450|carolina
# City not found. Skipping...
# Processing Record 451|novo aripuana
# Processing Record 452|rawah
# Processing Record 453|coquimbo
# Processing Record 454|opuwo
# Processing Record 455|cap malheureux
# Processing Record 456|bairiki
# Processing Record 457|nhulunbuy
# City not found. Skipping...
# Processing Record 458|aiken
# Processing Record 459|paamiut
# Processing Record 460|saryagash
# Processing Record 461|mackay
# Processing Record 462|khani
# Processing Record 463|tateyama
# Processing Record 464|siniscola
# City not found. Skipping...
# Processing Record 465|mujiayingzi
# Processing Record 466|dwarka
# Processing Record 467|machiques
# Processing Record 468|lodja
# Processing Record 469|urengoy
# Processing Record 470|paragominas
# Processing Record 471|bam
# Processing Record 472|albanel
# Processing Record 473|puerto escondido
# Processing Record 474|tessalit
# Processing Record 475|murom
# Processing Record 476|almenara
# Processing Record 477|grindavik
# Processing Record 478|mogadishu
# City not found. Skipping...
# Processing Record 479|mapiri
# City not found. Skipping...
# Processing Record 480|yeppoon
# Processing Record 481|dudinka
# Processing Record 482|san vicente
# Processing Record 483|pemberton
# Processing Record 484|tabuk
# Processing Record 485|kapit
# Processing Record 486|gisborne
# Processing Record 487|narsaq
# Processing Record 488|juegang
# Processing Record 489|tabivere
# Processing Record 490|manica
# Processing Record 491|soavinandriana
# Processing Record 492|general roca
# City not found. Skipping...
# Processing Record 493|xichang
# Processing Record 494|namatanai
# Processing Record 495|kijang
# Processing Record 496|praia da vitoria
# Processing Record 497|vadlapudi
# Processing Record 498|den helder
# Processing Record 499|zavetnoye
# Processing Record 500|ambovombe
# Processing Record 501|touros
# Processing Record 502|monforte de lemos
# Processing Record 503|comodoro rivadavia
# Processing Record 504|moron
# Processing Record 505|high rock
# Processing Record 506|whitecourt
# Processing Record 507|bolshaya glushitsa
# Processing Record 508|nisia floresta
# Processing Record 509|pandharpur
# Processing Record 510|kununurra
# Processing Record 511|skrunda
# Processing Record 512|ilhabela
# Processing Record 513|waipawa
# Processing Record 514|banon
# Processing Record 515|shadegan
# Processing Record 516|mareeba
# City not found. Skipping...
# Processing Record 517|kandrian
# Processing Record 518|cravo norte
# Processing Record 519|viseu
# Processing Record 520|fort frances
# Processing Record 521|asosa
# Processing Record 522|doka
# Processing Record 523|cotonou
# Processing Record 524|ponta delgada
# Processing Record 525|yambio
# Processing Record 526|ihosy
# Processing Record 527|novopskov
# Processing Record 528|tancanhuitz
# Processing Record 529|canico
# Processing Record 530|poykovskiy
# Processing Record 531|voznesenye
# City not found. Skipping...
# Processing Record 532|kakonko
# Processing Record 533|suchiapa
# Processing Record 534|san miguel
# Processing Record 535|richards bay
# City not found. Skipping...
# Processing Record 536|axim
# Processing Record 537|babylon
# City not found. Skipping...
# Processing Record 538|ralivka
# Processing Record 539|yanam
# City not found. Skipping...
# Processing Record 540|yarim
# Processing Record 541|noshiro
# Processing Record 542|hutchinson
# Processing Record 543|manta
# Processing Record 544|taonan
# Processing Record 545|avera
# Processing Record 546|bud
# Processing Record 547|davenda
# Processing Record 548|fondi
# Processing Record 549|sarahan
# Processing Record 550|oga
# City not found. Skipping...
# City not found. Skipping...

# %%
# Create a dictonary with the lists generated
weather_dict= {
    "City": city_name,
    "Country":country,
    "Temperature":temp,
    "Humidity": humidity,
    "Cloudiness":cloudiness, 
    "Wind Speed":wind_speed,
    "Latitude":latitude, 
    "Longtitude":longtitude,
    "Date":date
}

# Create a data frame from dictionary
weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
#              City Country  Temperature  Humidity  Cloudiness  Wind Speed  \
# 0          Albany      US       272.61        54         100        1.79
# 1            Lata      PT       285.66        83          93        5.15
# 2        Thompson      CA       268.15       100          90        4.10
# 3  Saint-Philippe      RE       296.89        73           0        1.00
# 4        Meulaboh      ID       298.01        84         100        1.89
#
#    Latitude  Longtitude        Date
# 0     42.60      -73.97  1607367231
# 1     40.16       -8.33  1607367231
# 2     55.74      -97.86  1607367231
# 3    -21.36       55.77  1607367231
# 4      4.14       96.13  1607367232

# %%
weather_data.describe()
# Out:
#        Temperature    Humidity  Cloudiness  Wind Speed    Latitude  \
# count   549.000000  549.000000  549.000000  549.000000  549.000000
# mean    284.052350   73.635701   53.265938    3.662951   20.665683
# std      15.806795   19.297571   40.681224    2.501712   33.693117
# min     235.440000    1.000000    0.000000    0.270000  -54.800000
# 25%     272.570000   64.000000    2.000000    1.710000   -6.470000
# 50%     288.150000   78.000000   67.000000    3.100000   26.620000
# 75%     298.010000   88.000000   94.000000    5.100000   49.500000
# max     310.410000  100.000000  100.000000   13.880000   78.220000
#
#        Longtitude          Date
# count  549.000000  5.490000e+02
# mean    21.475883  1.607367e+09
# std     92.071538  8.150403e+01
# min   -175.200000  1.607367e+09
# 25%    -65.100000  1.607367e+09
# 50%     24.730000  1.607367e+09
# 75%    100.660000  1.607367e+09
# max    179.320000  1.607367e+09

# %%
weather_data
# Out:
#                City Country  Temperature  Humidity  Cloudiness  Wind Speed  \
# 0            Albany      US       272.61        54         100        1.79
# 1              Lata      PT       285.66        83          93        5.15
# 2          Thompson      CA       268.15       100          90        4.10
# 3    Saint-Philippe      RE       296.89        73           0        1.00
# 4          Meulaboh      ID       298.01        84         100        1.89
# ..              ...     ...          ...       ...         ...         ...
# 544             Bud      US       274.62        64          90        4.60
# 545         Davenda      RU       256.41        90          51        1.40
# 546           Fondi      IT       283.19        71          64        1.79
# 547         Sarāhan      IN       281.52        49         100        2.55
# 548             Oga      IT       271.17        85          75        2.10
#
#      Latitude  Longtitude        Date
# 0       42.60      -73.97  1607367231
# 1       40.16       -8.33  1607367231
# 2       55.74      -97.86  1607367231
# 3      -21.36       55.77  1607367231
# 4        4.14       96.13  1607367232
# ..        ...         ...         ...
# 544     39.45      -86.18  1607367360
# 545     53.56      119.32  1607367360
# 546     41.35       13.43  1607367360
# 547     31.52       77.80  1607367360
# 548     46.46       10.35  1607367361
#
# [549 rows x 9 columns]

# %% [markdown]
# # Scatter Plots
#     *create a series of scatter plots to showcase the relationship Temperature, Humidity, and Wind Speed (mph) has with  Latitude

# %% [markdown]
# Temperature (F) vs. Latitude

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Latitude"], weather_data["Temperature"], marker="+", facecolors="red")

#title and labels
plt.title("Latitude vs. Temperature")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")

#saving the figure
plt.savefig("Latitude vs. Temperature.png")

# %% [markdown]
# Humidity (%) vs. Latitude

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Latitude"], weather_data["Humidity"], marker=".", facecolors="dimgray")

#title and labels
plt.title("Latitude vs. Humidity")
plt.ylabel("Humidity(%)")
plt.xlabel("Latitude")

#saving the figure
plt.savefig("Latitude vs. Humidity.png")

# %% [markdown]
# Cloudiness (%) vs. Latitude
#
#     *The figure below shoes there isn't a close relationship with latitude and cloudiness

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Latitude"], weather_data["Cloudiness"], marker="o", facecolors="rosybrown")

#title and labels
plt.title("Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")

#saving the figure
plt.savefig("Latitude vs. Cloudiness.png")

# Show plot
#plt.show()

# %% [markdown]
# Wind Speed (mph) vs. Latitude

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Latitude"], weather_data["Wind Speed"], marker="s", facecolors="goldenrod")

#title and labels
plt.title("Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")

#saving the figure
plt.savefig("Latitude vs. WindSpeed.png")

# %% [markdown]
# # Linear Regression

# %% [markdown]
# Run a linear regression on each relationship, separating the plots into Northern Hemisphere (greater than or equal to 0 degrees latitude) and Southern Hemisphere (less than 0 degrees latitude)

# %%
#creating and storing the northern hemisphere dataframe
northern_hemi=weather_data[weather_data['Latitude']>=0]
northern_hemi
# Out:
#          City Country  Temperature  Humidity  Cloudiness  Wind Speed  \
# 0      Albany      US       272.61        54         100        1.79
# 1        Lata      PT       285.66        83          93        5.15
# 2    Thompson      CA       268.15       100          90        4.10
# 4    Meulaboh      ID       298.01        84         100        1.89
# 6        Mama      RU       263.19        90         100        5.95
# ..        ...     ...          ...       ...         ...         ...
# 544       Bud      US       274.62        64          90        4.60
# 545   Davenda      RU       256.41        90          51        1.40
# 546     Fondi      IT       283.19        71          64        1.79
# 547   Sarāhan      IN       281.52        49         100        2.55
# 548       Oga      IT       271.17        85          75        2.10
#
#      Latitude  Longtitude        Date
# 0       42.60      -73.97  1607367231
# 1       40.16       -8.33  1607367231
# 2       55.74      -97.86  1607367231
# 4        4.14       96.13  1607367232
# 6       58.31      112.90  1607367232
# ..        ...         ...         ...
# 544     39.45      -86.18  1607367360
# 545     53.56      119.32  1607367360
# 546     41.35       13.43  1607367360
# 547     31.52       77.80  1607367360
# 548     46.46       10.35  1607367361
#
# [383 rows x 9 columns]

# %% [markdown]
# Northern Hemisphere: Temperature (F) vs. Latitude

# %%
x_values = northern_hemi['Latitude']
y_values = northern_hemi['Temperature']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
# Out:
# Text(0, 0.5, 'Temperature (F)')

# %% [markdown]
# Northern Hemisphere: Humidity (%) vs. Latitude

# %%
x_values = northern_hemi['Latitude']
y_values = northern_hemi['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
# Out:
# Text(0, 0.5, 'Humidity')

# %% [markdown]
# Northern Hemisphere: Cloudiness (%) vs. Latitude

# %%
x_values = northern_hemi['Latitude']
y_values = northern_hemi['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
# Out:
# Text(0, 0.5, 'Cloudiness')

# %% [markdown]
# Northern Hemisphere: Wind Speed (mph) vs. Latitude

# %%
x_values = northern_hemi['Latitude']
y_values = northern_hemi['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
# Out:
# Text(0, 0.5, 'Wind Speed')

# %%
#creating and storing the southern hemisphere dataframe
southern_hemi=weather_data[weather_data['Latitude']<0]
southern_hemi
# Out:
#                City Country  Temperature  Humidity  Cloudiness  Wind Speed  \
# 3    Saint-Philippe      RE       296.89        73           0        1.00
# 5           Rikitea      PF       297.27        78           0        7.66
# 7           Mataura      NZ       287.59        78           0        2.24
# 10             Lebu      CL       288.57        71           0        3.96
# 15    Nueva Londres      PY       304.11        34           0        2.66
# ..              ...     ...          ...       ...         ...         ...
# 515        Kandrian      PG       298.47        83         100        1.93
# 524           Ihosy      MG       294.60        87         100        3.49
# 530         Kakonko      TZ       291.41        89          96        0.73
# 533    Richards Bay      ZA       295.92        84         100        4.02
# 541           Manta      EC       297.54        78         100        5.54
#
#      Latitude  Longtitude        Date
# 3      -21.36       55.77  1607367231
# 5      -23.12     -134.97  1607367232
# 7      -46.19      168.86  1607367232
# 10     -37.62      -73.65  1607367233
# 15     -25.40      -56.55  1607367234
# ..        ...         ...         ...
# 515     -6.22      149.55  1607367353
# 524    -22.40       46.12  1607367355
# 530     -3.28       30.96  1607367356
# 533    -28.78       32.04  1607367357
# 541     -0.95      -80.73  1607367359
#
# [166 rows x 9 columns]

# %% [markdown]
# Southern Hemisphere: Temperature (F) vs. Latitude

# %%
x_values = southern_hemi['Latitude']
y_values = southern_hemi['Temperature']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
# Out:
# Text(0, 0.5, 'Temperature (F)')

# %% [markdown]
# Southern Hemisphere: Humidity (%) vs. Latitude

# %%
x_values = southern_hemi['Latitude']
y_values = southern_hemi['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
# Out:
# Text(0, 0.5, 'Humidity')

# %%
Southern Hemisphere: Cloudiness (%) vs. Latitude

# %%
x_values = southern_hemi['Latitude']
y_values = southern_hemi['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
# Out:
# Text(0, 0.5, 'Cloudiness')

# %%
Southern Hemisphere: Wind Speed (mph) vs. Latitude

# %%
x_values = southern_hemi['Latitude']
y_values = southern_hemi['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
# Out:
# Text(0, 0.5, 'Wind Speed')
